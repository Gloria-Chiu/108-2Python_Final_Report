# %% [markdown]
# #  各縣市老年人口現況分析

# %% [markdown]
# #  (圖二) 各縣市移入、移出數量

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
nep_districts = gpd.read_file(r'TWN_adm/TWN_adm2.shp') #讀取檔案 1
nep_districts
# Out:
#     ID_0  ISO  NAME_0  ID_1          NAME_1  ID_2          NAME_2  \
# 0    225  TWN  Taiwan     1       Kaohsiung     1  Kaohsiung City
# 1    225  TWN  Taiwan     2  Pratas Islands     2            None
# 2    225  TWN  Taiwan     3          Taipei     3     Taipei City
# 3    225  TWN  Taiwan     4          Taiwan     4        Changhwa
# 4    225  TWN  Taiwan     4          Taiwan     5          Chiayi
# 5    225  TWN  Taiwan     4          Taiwan     6         Hsinchu
# 6    225  TWN  Taiwan     4          Taiwan     7         Hualien
# 7    225  TWN  Taiwan     4          Taiwan     8            Ilan
# 8    225  TWN  Taiwan     4          Taiwan     9       Kaohsiung
# 9    225  TWN  Taiwan     4          Taiwan    10    Keelung City
# 10   225  TWN  Taiwan     4          Taiwan    11          Miaoli
# 11   225  TWN  Taiwan     4          Taiwan    12          Nantou
# 12   225  TWN  Taiwan     4          Taiwan    13          Penghu
# 13   225  TWN  Taiwan     4          Taiwan    14        Pingtung
# 14   225  TWN  Taiwan     4          Taiwan    15   Taichung City
# 15   225  TWN  Taiwan     4          Taiwan    16        Taichung
# 16   225  TWN  Taiwan     4          Taiwan    17     Tainan City
# 17   225  TWN  Taiwan     4          Taiwan    18          Tainan
# 18   225  TWN  Taiwan     4          Taiwan    19          Taipei
# 19   225  TWN  Taiwan     4          Taiwan    20         Taitung
# 20   225  TWN  Taiwan     4          Taiwan    21         Taoyuan
# 21   225  TWN  Taiwan     4          Taiwan    22          Yunlin
#
#             TYPE_2             ENGTYPE_2 NL_NAME_2                VARNAME_2  \
# 0       Chuan-shih  Special Municipality      None             Gaoxiong Shi
# 1             None                  None      None                     None
# 2       Chuan-shih  Special Municipality      None               Taibei Shi
# 3   District|Hsien                County      None        Zhanghua|Changhua
# 4   District|Hsien                County      None              Jiayi|Chiai
# 5   District|Hsien                County      None                   Xinzhu
# 6   District|Hsien                County      None                   Hualia
# 7   District|Hsien                County      None                    Yilan
# 8   District|Hsien                County      None                 Gaoxiong
# 9              Shi          Municipality      None  Jilong Shi|Chilung City
# 10  District|Hsien                County      None                     None
# 11  District|Hsien                County      None                     None
# 12  District|Hsien                County      None                     None
# 13  District|Hsien                County      None                 Pingdong
# 14             Shi          Municipality      None             Taizhong Shi
# 15  District|Hsien                County      None                 Taizhong
# 16             Shi          Municipality      None               Tainan Shi
# 17  District|Hsien                County      None                     None
# 18  District|Hsien                County      None                   Taibei
# 19  District|Hsien                County      None                  Taidong
# 20  District|Hsien                County      None                     None
# 21  District|Hsien                County      None                 YÃ¼anlin
#
#                                              geometry
# 0   MULTIPOLYGON (((120.23904 22.75155, 120.23875 ...
# 1   POLYGON ((116.71722 20.70959, 116.71778 20.709...
# 2   POLYGON ((121.52582 24.95191, 121.45911 24.930...
# 3   MULTIPOLYGON (((120.46427 24.16347, 120.46403 ...
# 4   MULTIPOLYGON (((120.13403 23.37264, 120.13403 ...
# 5   MULTIPOLYGON (((121.25690 24.36170, 121.22860 ...
# 6   MULTIPOLYGON (((120.99192 23.47921, 121.06472 ...
# 7   MULTIPOLYGON (((121.84292 24.47625, 121.84236 ...
# 8   MULTIPOLYGON (((120.33847 22.55153, 120.33847 ...
# 9   MULTIPOLYGON (((121.78680 25.19514, 121.78680 ...
# 10  POLYGON ((120.61208 24.42708, 120.61236 24.427...
# 11  POLYGON ((120.66179 23.60818, 120.61855 23.632...
# 12  MULTIPOLYGON (((119.60152 23.78809, 119.60152 ...
# 13  MULTIPOLYGON (((120.69653 22.04070, 120.69653 ...
# 14  POLYGON ((120.67641 24.10113, 120.62354 24.098...
# 15  POLYGON ((120.46403 24.16380, 120.46403 24.164...
# 16  POLYGON ((120.06989 23.05090, 120.10577 23.064...
# 17  MULTIPOLYGON (((120.08847 23.12097, 120.08875 ...
# 18  MULTIPOLYGON (((122.07875 25.63431, 122.07875 ...
# 19  MULTIPOLYGON (((121.11347 22.71181, 121.11292 ...
# 20  POLYGON ((121.41455 24.67959, 121.38832 24.625...
# 21  MULTIPOLYGON (((120.66179 23.60818, 120.60052 ...

# %%
#擷取其中兩欄
nep_districts = nep_districts[['NAME_2', 'geometry']]
nep_districts.rename(columns = {'NAME_2' : 'District'}, inplace = True)
# Out:
# C:\Users\gloria\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
nep_districts
# Out:
#           District                                           geometry
# 0   Kaohsiung City  MULTIPOLYGON (((120.23904 22.75155, 120.23875 ...
# 1             None  POLYGON ((116.71722 20.70959, 116.71778 20.709...
# 2      Taipei City  POLYGON ((121.52582 24.95191, 121.45911 24.930...
# 3         Changhwa  MULTIPOLYGON (((120.46427 24.16347, 120.46403 ...
# 4           Chiayi  MULTIPOLYGON (((120.13403 23.37264, 120.13403 ...
# 5          Hsinchu  MULTIPOLYGON (((121.25690 24.36170, 121.22860 ...
# 6          Hualien  MULTIPOLYGON (((120.99192 23.47921, 121.06472 ...
# 7             Ilan  MULTIPOLYGON (((121.84292 24.47625, 121.84236 ...
# 8        Kaohsiung  MULTIPOLYGON (((120.33847 22.55153, 120.33847 ...
# 9     Keelung City  MULTIPOLYGON (((121.78680 25.19514, 121.78680 ...
# 10          Miaoli  POLYGON ((120.61208 24.42708, 120.61236 24.427...
# 11          Nantou  POLYGON ((120.66179 23.60818, 120.61855 23.632...
# 12          Penghu  MULTIPOLYGON (((119.60152 23.78809, 119.60152 ...
# 13        Pingtung  MULTIPOLYGON (((120.69653 22.04070, 120.69653 ...
# 14   Taichung City  POLYGON ((120.67641 24.10113, 120.62354 24.098...
# 15        Taichung  POLYGON ((120.46403 24.16380, 120.46403 24.164...
# 16     Tainan City  POLYGON ((120.06989 23.05090, 120.10577 23.064...
# 17          Tainan  MULTIPOLYGON (((120.08847 23.12097, 120.08875 ...
# 18          Taipei  MULTIPOLYGON (((122.07875 25.63431, 122.07875 ...
# 19         Taitung  MULTIPOLYGON (((121.11347 22.71181, 121.11292 ...
# 20         Taoyuan  POLYGON ((121.41455 24.67959, 121.38832 24.625...
# 21          Yunlin  MULTIPOLYGON (((120.66179 23.60818, 120.60052 ...

# %%
nep_districts.crs #確認座標系統
# Out:
# {'init': 'epsg:4326'}

# %%
mn = pd.read_csv("migrate area.csv",encoding ="big5") #讀取檔案2
mn
# Out:
#              District  net migrate(one year)
# 0     New Taipei City                -2796.0
# 1         Taipei City               -19939.2
# 2        Taoyuan City                24768.0
# 3       Taichung City                12057.6
# 4         Tainan City                 -340.8
# 5      Kaohsiung City                -3912.0
# 6        Yilan County                 -252.0
# 7      Hsinchu County                 3957.6
# 8       Miaoli County                -4010.4
# 9     Changhua County                -8330.4
# 10      Nantou County                -1855.2
# 11      Yunlin County                   -2.4
# 12      Chiayi County                 -969.6
# 13    Pingtung County                  628.8
# 14     Taitung County                 1404.0
# 15     Hualien County                  189.6
# 16      Penghu County                  110.4
# 17     Keelung County                 -122.4
# 18       Hsinchy City                 3350.4
# 19        Chiayi city                 -508.8
# 20      Kinmen County                  458.4
# 21  Lienchiang County                  230.4

# %%
#確認檔案2中的欄位有哪些
for migrate_area in mn:
    print(migrate_area)
# Out:
# District
# net migrate(one year)

# %%
#擷取檔案2其中兩欄
migrate_area = mn[['District','net migrate(one year)']]

# %%
migrate_area
# Out:
#              District  net migrate(one year)
# 0     New Taipei City                -2796.0
# 1         Taipei City               -19939.2
# 2        Taoyuan City                24768.0
# 3       Taichung City                12057.6
# 4         Tainan City                 -340.8
# 5      Kaohsiung City                -3912.0
# 6        Yilan County                 -252.0
# 7      Hsinchu County                 3957.6
# 8       Miaoli County                -4010.4
# 9     Changhua County                -8330.4
# 10      Nantou County                -1855.2
# 11      Yunlin County                   -2.4
# 12      Chiayi County                 -969.6
# 13    Pingtung County                  628.8
# 14     Taitung County                 1404.0
# 15     Hualien County                  189.6
# 16      Penghu County                  110.4
# 17     Keelung County                 -122.4
# 18       Hsinchy City                 3350.4
# 19        Chiayi city                 -508.8
# 20      Kinmen County                  458.4
# 21  Lienchiang County                  230.4

# %%
# 在擷取後的表格中多加一欄
for index, row in migrate_area.iterrows():
    if '[' and ']' in row['District']:
        start_index = row['District'].find('[')
        end_index = row['District'].find(']')
        migrate_area.loc[index, 'District2'] = migrate_area.loc[index]['District'][start_index+1: end_index]
        
    else:
        migrate_area.loc[index, 'District2'] = migrate_area.loc[index]['District']

# %%
migrate_area
# Out:
#              District  net migrate(one year)          District2
# 0     New Taipei City                -2796.0    New Taipei City
# 1         Taipei City               -19939.2        Taipei City
# 2        Taoyuan City                24768.0       Taoyuan City
# 3       Taichung City                12057.6      Taichung City
# 4         Tainan City                 -340.8        Tainan City
# 5      Kaohsiung City                -3912.0     Kaohsiung City
# 6        Yilan County                 -252.0       Yilan County
# 7      Hsinchu County                 3957.6     Hsinchu County
# 8       Miaoli County                -4010.4      Miaoli County
# 9     Changhua County                -8330.4    Changhua County
# 10      Nantou County                -1855.2      Nantou County
# 11      Yunlin County                   -2.4      Yunlin County
# 12      Chiayi County                 -969.6      Chiayi County
# 13    Pingtung County                  628.8    Pingtung County
# 14     Taitung County                 1404.0     Taitung County
# 15     Hualien County                  189.6     Hualien County
# 16      Penghu County                  110.4      Penghu County
# 17     Keelung County                 -122.4     Keelung County
# 18       Hsinchy City                 3350.4       Hsinchy City
# 19        Chiayi city                 -508.8        Chiayi city
# 20      Kinmen County                  458.4      Kinmen County
# 21  Lienchiang County                  230.4  Lienchiang County

# %%
#檢查檔案1和檔案2的欄位是否可以對到
for index, row in nep_districts['District'].iteritems():
    if row in migrate_area['District'].tolist():
        pass
    else:
        print('The district ', row , ' is NOT in the migrate_area list')
# Out:
# The district  None  is NOT in the migrate_area list
# The district  Changhwa  is NOT in the migrate_area list
# The district  Chiayi  is NOT in the migrate_area list
# The district  Hsinchu  is NOT in the migrate_area list
# The district  Hualien  is NOT in the migrate_area list
# The district  Ilan  is NOT in the migrate_area list
# The district  Kaohsiung  is NOT in the migrate_area list
# The district  Keelung City  is NOT in the migrate_area list
# The district  Miaoli  is NOT in the migrate_area list
# The district  Nantou  is NOT in the migrate_area list
# The district  Penghu  is NOT in the migrate_area list
# The district  Pingtung  is NOT in the migrate_area list
# The district  Taichung  is NOT in the migrate_area list
# The district  Tainan  is NOT in the migrate_area list
# The district  Taipei  is NOT in the migrate_area list
# The district  Taitung  is NOT in the migrate_area list
# The district  Taoyuan  is NOT in the migrate_area list
# The district  Yunlin  is NOT in the migrate_area list

# %%
#修正檔案1、2中無法對到的欄位名稱
nep_districts.replace('Changhwa', 'Changhua County', inplace = True)
nep_districts.replace('Chiayi', 'Chiayi County', inplace = True)
nep_districts.replace('Hsinchu', 'Hsinchu County', inplace = True)
nep_districts.replace('Hualien', 'Hualien County', inplace = True)
nep_districts.replace('Ilan', 'Yilan County', inplace = True)
nep_districts.replace('Kaohsiung', 'Kaohsiung City', inplace = True)
nep_districts.replace('Keelung City', 'Keelung City', inplace = True)
nep_districts.replace('Miaoli', 'Miaoli County', inplace = True)
nep_districts.replace('Nantou', 'Nantou County', inplace = True)
nep_districts.replace('Penghu', 'Penghu County', inplace = True)
nep_districts.replace('Pingtung', 'Pingtung County', inplace = True)
nep_districts.replace('Taichung', 'Taichung City', inplace = True)
nep_districts.replace('Tainan', 'Tainan City', inplace = True)
nep_districts.replace('Taipei', 'Taipei City', inplace = True)
nep_districts.replace('Taitung', 'Taitung County', inplace = True)
nep_districts.replace('Taoyuan', 'Taoyuan City', inplace = True)
nep_districts.replace('Yunlin', 'Yunlin County', inplace = True)
# Out:
# C:\Users\gloria\Anaconda3\lib\site-packages\pandas\core\frame.py:4263: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
nep_districts
# Out:
#            District                                           geometry
# 0    Kaohsiung City  (POLYGON ((120.2390365600586 22.7515544891358,...
# 1              None  POLYGON ((116.7172241210938 20.70959472656256,...
# 2       Taipei City  POLYGON ((121.5258178710939 24.95191001892101,...
# 3   Changhua County  (POLYGON ((120.4642715454102 24.1634731292724,...
# 4     Chiayi County  (POLYGON ((120.1340255737306 23.37264060974132...
# 5    Hsinchu County  (POLYGON ((121.2568969726563 24.3617000579834,...
# 6    Hualien County  (POLYGON ((120.9919204711915 23.47921180725092...
# 7      Yilan County  (POLYGON ((121.8429183959961 24.47624969482428...
# 8    Kaohsiung City  (POLYGON ((120.3384704589845 22.55152702331554...
# 9      Keelung City  (POLYGON ((121.7868041992188 25.19513893127447...
# 10    Miaoli County  POLYGON ((120.6120834350586 24.42708396911621,...
# 11    Nantou County  POLYGON ((120.6617889404298 23.60818290710461,...
# 12    Penghu County  (POLYGON ((119.6015243530273 23.78808593750006...
# 13  Pingtung County  (POLYGON ((120.6965255737305 22.04069709777832...
# 14    Taichung City  POLYGON ((120.6764068603518 24.10112953186041,...
# 15    Taichung City  POLYGON ((120.4640274047852 24.16379928588862,...
# 16      Tainan City  POLYGON ((120.0698928833009 23.05090141296398,...
# 17      Tainan City  (POLYGON ((120.0884704589844 23.12097358703625...
# 18      Taipei City  (POLYGON ((122.0787506103517 25.63430595397955...
# 19   Taitung County  (POLYGON ((121.1134719848633 22.71180534362793...
# 20     Taoyuan City  POLYGON ((121.4145507812502 24.67958831787121,...
# 21    Yunlin County  (POLYGON ((120.6617889404298 23.60818290710461...

# %%
migrate_area
# Out:
#              District  net migrate(one year)          District2
# 0     New Taipei City                -2796.0    New Taipei City
# 1         Taipei City               -19939.2        Taipei City
# 2        Taoyuan City                24768.0       Taoyuan City
# 3       Taichung City                12057.6      Taichung City
# 4         Tainan City                 -340.8        Tainan City
# 5      Kaohsiung City                -3912.0     Kaohsiung City
# 6        Yilan County                 -252.0       Yilan County
# 7      Hsinchu County                 3957.6     Hsinchu County
# 8       Miaoli County                -4010.4      Miaoli County
# 9     Changhua County                -8330.4    Changhua County
# 10      Nantou County                -1855.2      Nantou County
# 11      Yunlin County                   -2.4      Yunlin County
# 12      Chiayi County                 -969.6      Chiayi County
# 13    Pingtung County                  628.8    Pingtung County
# 14     Taitung County                 1404.0     Taitung County
# 15     Hualien County                  189.6     Hualien County
# 16      Penghu County                  110.4      Penghu County
# 17     Keelung County                 -122.4     Keelung County
# 18       Hsinchy City                 3350.4       Hsinchy City
# 19        Chiayi city                 -508.8        Chiayi city
# 20      Kinmen County                  458.4      Kinmen County
# 21  Lienchiang County                  230.4  Lienchiang County

# %%
#結合檔案1、2
nep_districts = nep_districts.merge(migrate_area, on = 'District')
nep_districts
# Out:
#            District                                           geometry  \
# 0    Kaohsiung City  MULTIPOLYGON (((120.23904 22.75155, 120.23875 ...
# 1    Kaohsiung City  MULTIPOLYGON (((120.33847 22.55153, 120.33847 ...
# 2       Taipei City  POLYGON ((121.52582 24.95191, 121.45911 24.930...
# 3       Taipei City  MULTIPOLYGON (((122.07875 25.63431, 122.07875 ...
# 4   Changhua County  MULTIPOLYGON (((120.46427 24.16347, 120.46403 ...
# 5     Chiayi County  MULTIPOLYGON (((120.13403 23.37264, 120.13403 ...
# 6    Hsinchu County  MULTIPOLYGON (((121.25690 24.36170, 121.22860 ...
# 7    Hualien County  MULTIPOLYGON (((120.99192 23.47921, 121.06472 ...
# 8      Yilan County  MULTIPOLYGON (((121.84292 24.47625, 121.84236 ...
# 9     Miaoli County  POLYGON ((120.61208 24.42708, 120.61236 24.427...
# 10    Nantou County  POLYGON ((120.66179 23.60818, 120.61855 23.632...
# 11    Penghu County  MULTIPOLYGON (((119.60152 23.78809, 119.60152 ...
# 12  Pingtung County  MULTIPOLYGON (((120.69653 22.04070, 120.69653 ...
# 13    Taichung City  POLYGON ((120.67641 24.10113, 120.62354 24.098...
# 14    Taichung City  POLYGON ((120.46403 24.16380, 120.46403 24.164...
# 15      Tainan City  POLYGON ((120.06989 23.05090, 120.10577 23.064...
# 16      Tainan City  MULTIPOLYGON (((120.08847 23.12097, 120.08875 ...
# 17   Taitung County  MULTIPOLYGON (((121.11347 22.71181, 121.11292 ...
# 18     Taoyuan City  POLYGON ((121.41455 24.67959, 121.38832 24.625...
# 19    Yunlin County  MULTIPOLYGON (((120.66179 23.60818, 120.60052 ...
#
#     net migrate(one year)        District2
# 0                 -3912.0   Kaohsiung City
# 1                 -3912.0   Kaohsiung City
# 2                -19939.2      Taipei City
# 3                -19939.2      Taipei City
# 4                 -8330.4  Changhua County
# 5                  -969.6    Chiayi County
# 6                  3957.6   Hsinchu County
# 7                   189.6   Hualien County
# 8                  -252.0     Yilan County
# 9                 -4010.4    Miaoli County
# 10                -1855.2    Nantou County
# 11                  110.4    Penghu County
# 12                  628.8  Pingtung County
# 13                12057.6    Taichung City
# 14                12057.6    Taichung City
# 15                 -340.8      Tainan City
# 16                 -340.8      Tainan City
# 17                 1404.0   Taitung County
# 18                24768.0     Taoyuan City
# 19                   -2.4    Yunlin County

# %%
# 印出我們要的各縣市淨遷徙比較圖
nep_districts.plot(column = 'net migrate(one year)', cmap =plt.cm.coolwarm, legend = True)

# %% [raw]
# 我們發現兩個特徵：
# 一、臺中市移入人口高
#  1.周邊縣市有人口移出的現象，特別是彰化縣
#  2.臺中市受產業趨勢影響，擁有發展潛力，吸引人口移入
#
# 二、桃園市移入人口高
#  1.相較雙北房價較低加上高鐵與捷運發達，青壯年選擇居住於此
#  2.桃園市和臺中市晉升為六都，吸引周邊縣市青壯年
